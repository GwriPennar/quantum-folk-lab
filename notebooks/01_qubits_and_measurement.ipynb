# %% [markdown]
# # Qubits and Measurement
#
# This notebook is a thin companion to EXP-001. Core logic lives in `quantum_folk_lab`.

# %%
from quantum_folk_lab.quantum_basics import list_experiments
from quantum_folk_lab.simulation import run_basics_experiment

[experiment.name for experiment in list_experiments()]

# %% [markdown]
# A qubit state has amplitudes over `|0>` and `|1>`. Measurement samples outcomes according to squared amplitude magnitudes.

# %%
run_basics_experiment("zero", shots=1024).to_dict()

# %%
run_basics_experiment("hadamard", shots=4096).to_dict()
